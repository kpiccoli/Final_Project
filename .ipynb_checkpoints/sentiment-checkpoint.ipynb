# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# NLTK VADER for sentiment analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='

# %%
news_tables = {}
tickers = ['AMZN', 'TSLA', 'GOOG']

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables['AMZN']
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# Why Target Stock Is Hopping and Walmart Is Slipping. Both Had Strong Earnings.
# Aug-19-20 02:37PM
# Trump Likes The Idea Of Oracle Buying TikTok. Analysts Arent Convinced.
# 01:50PM
# Amazon to add thousands of jobs to Phoenix metro area
# 01:30PM
# Zoom Video to Soon Appear on Amazon, Facebook, and Google Smart Display Devices
# 01:14PM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN',
#   'Aug-19-20',
#   '02:37PM',
#   'Why Target Stock Is Hopping and Walmart Is Slipping. Both Had Strong Earnings.'],
#  ['AMZN',
#   'Aug-19-20',
#   '01:50PM',
#   'Trump Likes The Idea Of Oracle Buying TikTok. Analysts Arent Convinced.'],
#  ['AMZN',
#   'Aug-19-20',
#   '01:30PM',
#   'Amazon to add thousands of jobs to Phoenix metro area'],
#  ['AMZN',
#   'Aug-19-20',
#   '01:14PM',
#   'Zoom Video to Soon Appear on Amazon, Facebook, and Google Smart Display Devices'],
#  ['AMZN',
#   'Aug-19-20',
#   '01:10PM',
#   "1 Surprising Number From Walmart's Second Quarter Report"],
#  ['AMZN',
#   'Aug-19-20',
#   '12:14PM',
#   'Apple Breaks $2 Trillion Barrier in Latest Rally Milestone'],
#  ['AMZN',
#   'Aug-19-20',
#   '12:10PM',
#   'Amazon Wins\xa0Loyal Walmart Shoppers as Americans Stampede Online'],
#  ['AMZN',
#   'Aug-19-20',
#   '12:04PM',
#   'Amazon ramps up pressure on Walmart with fresh moves in online grocery'],
#  ['AMZN', 'Aug-19-20', '11:58AM', 'Why Target Is Soaring Today'],
#  ['AMZN',
#   'Aug-19-20',
#   '11:51AM',
#   'Dow Jones Rallies 125 Points, As Nasdaq, S&P 500 Set Records; Apple Market Cap Tops $2 Trillion'],
#  ['AMZN', 'Aug-19-20', '11:41AM', 'Better Buy: Costco Wholesale vs. Walmart'],
#  ['AMZN',
#   'Aug-19-20',
#   '11:28AM',
#   "2 Surprising Changes Attacking Amazon's Dominance"],
#  ['AMZN',
#   'Aug-19-20',
#   '11:28AM',
#   "Zoom Video's for home service to expand to Amazon's Echo, Facebook's Portal and Google's Nest"],
#  ['AMZN', 'Aug-19-20', '11:27AM', 'Why Is Home Depot Stock Down?'],
#  ['AMZN',
#   'Aug-19-20',
#   '11:25AM',
#   'A tale told by an idiot  CNBCs Jim Cramer urges investors not to be fooled by new highs in the stock market'],
#  ['AMZN',
#   'Aug-19-20',
#   '11:21AM',
#   'Apple Is First U.S. Company to Reach $2 Trillion Market Value'],
#  ['AMZN',
#   'Aug-19-20',
#   '11:01AM',
#   "Apple's Market Cap Just Hit $2 Trillion, but Is the Stock a Buy?"],
#  ['AMZN', 'Aug-19-20', '10:39AM', 'How Berkshire Is Hedging Against Disaster'],
#  ['AMZN', 'Aug-19-20', '10:31AM', '7 Donts Investors Must Know'],
#  ['AMZN',
#   'Aug-19-20',
#   '10:15AM',
#   "US STOCKS-S&P 500 notches record high for second day after Target, Lowe's results beat"],
#  ['AMZN',
#   'Aug-19-20',
#   '10:12AM',
#   'Shoppers Spending Cuts May Continue Through Holiday Season'],
#  ['AMZN',
#   'Aug-19-20',
#   '10:12AM',
#   "There's No Weakness in Target's Blowout Quarter, Here's How to Trade It"],
#  ['AMZN',
#   'Aug-19-20',
#   '09:34AM',
#   'Targets Digital Sales Drive a Record Quarter'],
#  ['AMZN', 'Aug-19-20', '09:24AM', '3 Reasons Walmart Crushed Q2 Earnings'],
#  ['AMZN',
#   'Aug-19-20',
#   '09:24AM',
#   'Target Stock Pops 8% Because Its Sales Are Way Better Than Walmarts'],
#  ['AMZN',
#   'Aug-19-20',
#   '09:00AM',
#   "Column: A year ago, CEOs pledged to serve stakeholders, not shareholders. Don't believe them"],
#  ['AMZN',
#   'Aug-19-20',
#   '08:55AM',
#   '3 Ways Zynga Is Killing It in Mobile Games'],
#  ['AMZN',
#   'Aug-19-20',
#   '08:14AM',
#   "Dow Jones Futures: Amazon, Google Flash Buy Signals In Stock Market Rally; Target, Lowe's Crush Views"],
#  ['AMZN',
#   'Aug-19-20',
#   '07:41AM',
#   'GLOBAL MARKETS-Shares gain as Wall Street record outweighs jitters over growth'],
#  ['AMZN', 'Aug-19-20', '07:30AM', '2 E-Commerce Stocks Poised for a Bull Run'],
#  ['AMZN',
#   'Aug-19-20',
#   '07:05AM',
#   'Kind of Lousy Markets, Washington Stimulus? FOMC Minutes, Watching Amazon'],
#  ['AMZN',
#   'Aug-19-20',
#   '07:00AM',
#   '2 Growth Stocks to Buy and Hold for the Next 50 Years'],
#  ['AMZN',
#   'Aug-19-20',
#   '06:35AM',
#   'Amazon expands Morrisons deal with full-range offer'],
#  ['AMZN',
#   'Aug-19-20',
#   '05:45AM',
#   'Amazon expands Morrisons deal with full-range offer'],
#  ['AMZN',
#   'Aug-19-20',
#   '05:42AM',
#   'Amazon expands Morrisons deal with full-range offer'],
#  ['AMZN',
#   'Aug-19-20',
#   '05:23AM',
#   'Amazon and Ambanis Jio Are Spoiling for an Epic India Fight'],
#  ['AMZN',
#   'Aug-19-20',
#   '05:00AM',
#   'Housing Starts Up 22.6% in July, and Two More Numbers to Know'],
#  ['AMZN',
#   'Aug-19-20',
#   '04:26AM',
#   'GLOBAL MARKETS-Shares nudge up as Wall Street record outweighs jitters on growth'],
#  ['AMZN',
#   'Aug-19-20',
#   '02:35AM',
#   'Amazon Thinks Future Of Work Is At The Office, Buys Real Estate In Six Major US Cities'],
#  ['AMZN',
#   'Aug-19-20',
#   '02:28AM',
#   'PRESS DIGEST - Wall Street Journal - Aug. 19'],
#  ['AMZN',
#   'Aug-18-20',
#   '09:12PM',
#   'Amazon Makes It Harder for Sellers to Avoid Shipping Service'],
#  ['AMZN', 'Aug-18-20', '08:41PM', 'PRESS DIGEST-British Business - Aug. 19'],
#  ['AMZN', 'Aug-18-20', '07:44PM', 'S&P 500 Closes at New All-Time High'],
#  ['AMZN',
#   'Aug-18-20',
#   '06:27PM',
#   "We're Back: S&P 500 Reaches All-Time High, Walmart, Home Depot Earnings, Oracle TikTok Play, Buffett Selling Stocks in 2020"],
#  ['AMZN',
#   'Aug-18-20',
#   '05:56PM',
#   'Oracles Improbable TikTok Talks Have a Simple Explanation: Data'],
#  ['AMZN',
#   'Aug-18-20',
#   '05:52PM',
#   'Amazon Postal Deal That Trump Despises Is Actually Profitable'],
#  ['AMZN',
#   'Aug-18-20',
#   '04:58PM',
#   "Here's What Warren Buffett Is Buying and Selling"],
#  ['AMZN',
#   'Aug-18-20',
#   '04:36PM',
#   'US STOCKS-The pandemic bull market: S&P 500 closes at record high'],
#  ['AMZN',
#   'Aug-18-20',
#   '04:33PM',
#   'GLOBAL MARKETS-Stocks rally on new U.S. highs, dollar at 2-year low'],
#  ['AMZN',
#   'Aug-18-20',
#   '04:25PM',
#   'Netflix Inc. stock rises Tuesday, outperforms market'],
#  ['AMZN',
#   'Aug-18-20',
#   '04:25PM',
#   'Amazon.com Inc. stock outperforms competitors on strong trading day'],
#  ['AMZN',
#   'Aug-18-20',
#   '04:25PM',
#   '3M Co. stock underperforms Tuesday when compared to competitors'],
#  ['AMZN',
#   'Aug-18-20',
#   '04:23PM',
#   "Brazil's Magazine Luiza eyes wide range of potential acquisitions"],
#  ['AMZN',
#   'Aug-18-20',
#   '04:06PM',
#   'The Stock Markets Improbable Recovery Explained'],
#  ['AMZN',
#   'Aug-18-20',
#   '04:00PM',
#   'US STOCKS-S&P 500 hits record closing high, regaining pre-COVID level'],
#  ['AMZN',
#   'Aug-18-20',
#   '03:08PM',
#   'GLOBAL MARKETS-Stocks rally on new U.S. highs, dollar at 2-year low'],
#  ['AMZN', 'Aug-18-20', '03:04PM', 'Why Doing Homework Is Important'],
#  ['AMZN',
#   'Aug-18-20',
#   '02:59PM',
#   "India's Reliance Retail acquires a majority stake in online pharmacy Nedmeds' parent firm for $83.2M"],
#  ['AMZN',
#   'Aug-18-20',
#   '02:33PM',
#   'US STOCKS-S&P 500 hits new intraday record, regaining pre-COVID levels'],
#  ['AMZN',
#   'Aug-18-20',
#   '02:07PM',
#   'Senate Republicans to Introduce New Stimulus Bill'],
#  ['AMZN',
#   'Aug-18-20',
#   '01:45PM',
#   'US STOCKS-S&P 500 on track for record closing high'],
#  ['AMZN',
#   'Aug-18-20',
#   '01:38PM',
#   'S&P 500 Reaches Record High, But Many Stocks Sit Out The Celebration'],
#  ['AMZN',
#   'Aug-18-20',
#   '01:31PM',
#   'Peloton, DraftKings, JD.com: Midday Tech Stock Movers'],
#  ['AMZN',
#   'Aug-18-20',
#   '01:08PM',
#   'Eros STX Sees Itself as a $1 Billion Business in 2022'],
#  ['AMZN',
#   'Aug-18-20',
#   '12:45PM',
#   'GRAPHIC-Big Tech drives S&P 500 to record high in coronavirus rally'],
#  ['AMZN',
#   'Aug-18-20',
#   '12:31PM',
#   'His fund has lost $21 billion this year  now hes warning investors could be in for even more turbulence this fall'],
#  ['AMZN', 'Aug-18-20', '12:09PM', '3 Future 10-Baggers to Watch'],
#  ['AMZN',
#   'Aug-18-20',
#   '11:41AM',
#   'Walmart says government stimulus money bolstered Q2s blowout results and analysts are concerned now that its been spent'],
#  ['AMZN',
#   'Aug-18-20',
#   '11:37AM',
#   'What Google and Amazon are doing to comply with Californias new privacy law'],
#  ['AMZN',
#   'Aug-18-20',
#   '11:30AM',
#   'Dow Jones Flat, But S&P 500 Hits All-Time High; FANG Stock Gives New Buy Signal'],
#  ['AMZN', 'Aug-18-20', '11:05AM', 'Amazon Hiring 3,500 New Workers'],
#  ['AMZN', 'Aug-18-20', '11:00AM', 'Better Buy: Amazon vs. GameStop'],
#  ['AMZN',
#   'Aug-18-20',
#   '10:55AM',
#   'US STOCKS-S&P 500 reclaims Feb highs, then retreats'],
#  ['AMZN',
#   'Aug-18-20',
#   '10:50AM',
#   'Bill Gates, Elon Musk, Jeff Bezos and the rest of the Oligarchic Dozen just reached a disturbing milestone'],
#  ['AMZN',
#   'Aug-18-20',
#   '10:47AM',
#   'Walmart Blows Past Estimates in Its Second Quarter'],
#  ['AMZN',
#   'Aug-18-20',
#   '10:35AM',
#   'Have $1,000? 2 Top Coronavirus Stocks to Buy and Hold for the Next Decade (or Longer)'],
#  ['AMZN', 'Aug-18-20', '10:29AM', 'Better Buy: Walt Disney vs. Walmart'],
#  ['AMZN', 'Aug-18-20', '10:27AM', 'Walmart Sends a Warning to Washington'],
#  ['AMZN',
#   'Aug-18-20',
#   '10:24AM',
#   'Amazon Bets on Physical Office Space as Others Go Virtual'],
#  ['AMZN',
#   'Aug-18-20',
#   '10:11AM',
#   'Amazon (AMZN) Boosts AWS Cloud Portfolio With Amazon Braket'],
#  ['AMZN',
#   'Aug-18-20',
#   '10:10AM',
#   'Dow Jones Falls 100 Points Amid Earnings From Home Depot, Walmart; S&P 500 Hits Record High, While Amazon, Tesla Jump'],
#  ['AMZN',
#   'Aug-18-20',
#   '10:00AM',
#   "3 Ways COVID-19 Shifts Boosted eBay's Business"],
#  ['AMZN',
#   'Aug-18-20',
#   '09:56AM',
#   'S&P 500 completes recovery from COVID-19 sell-off, hits record high'],
#  ['AMZN',
#   'Aug-18-20',
#   '09:34AM',
#   'This Expensive Growth Stock Hasnt Peaked Yet'],
#  ['AMZN',
#   'Aug-18-20',
#   '09:29AM',
#   "3 Must-See Numbers in JD's Q2 Earnings Report"],
#  ['AMZN',
#   'Aug-18-20',
#   '09:13AM',
#   'Afraid of Election Chaos Hitting the Stock Market? Theres an Options Trade for That.'],
#  ['AMZN',
#   'Aug-18-20',
#   '09:00AM',
#   "As One Might Expect, Retailers Don't Like Using Amazon for Cloud Services"],
#  ['AMZN',
#   'Aug-18-20',
#   '08:30AM',
#   'SoftBank Is Betting Big on U.S. Tech Megacaps'],
#  ['AMZN',
#   'Aug-18-20',
#   '08:06AM',
#   'SoftBank Made Big Bets on Amazon, Tesla, and 23 Other Tech Stocks. The Timing Was Perfect.'],
#  ['AMZN',
#   'Aug-18-20',
#   '08:00AM',
#   'COVID helps Canadian logistics robot firm Attabotics raise $50 million'],
#  ['AMZN',
#   'Aug-18-20',
#   '07:44AM',
#   'Toyota Teams Up With Amazon for Cloud-Based Data Services'],
#  ['AMZN',
#   'Aug-18-20',
#   '07:32AM',
#   'Worlds Biggest Wealth Fund Wants Clarification on New CEO'],
#  ['AMZN',
#   'Aug-18-20',
#   '07:00AM',
#   'Why Amazon Is Like Steroids for Your Portfolio'],
#  ['AMZN', 'Aug-18-20', '07:00AM', 'Is Genius Brands Stock a Buy?'],
#  ['AMZN',
#   'Aug-18-20',
#   '06:23AM',
#   'Asias Richest Man Is on a Shopping Spree in Race Against Amazon'],
#  ['AMZN',
#   'Aug-18-20',
#   '06:06AM',
#   'Yikes! Buffett Has Now Sold 32 Stocks in 6 Months'],
#  ['AMZN',
#   'Aug-18-20',
#   '06:00AM',
#   'Amazon Announces Plans to Create 3,500 New Jobs in U.S. Tech Hubs in Dallas, Detroit, Denver, New York, Phoenix, and San Diego'],
#  ['AMZN', 'Aug-18-20', '06:00AM', '2 Top Stocks Under $5'],
#  ['AMZN',
#   'Aug-18-20',
#   '05:30AM',
#   'Trump Cant Hide His True Reason for Derailing the Post Office'],
#  ['AMZN',
#   'Aug-18-20',
#   '05:20AM',
#   'Amazon to add 3,500 office jobs in six locations: WSJ'],
#  ['TSLA',
#   'Aug-19-20',
#   '02:45PM',
#   'Trading Tesla After Its 40% Rally in Five Days'],
#  ['TSLA',
#   'Aug-19-20',
#   '01:15PM',
#   'Tesla Gigafactory 1 to Boost Battery Production Capacity 10% After New $100 Million Panasonic Investment'],
#  ['TSLA',
#   'Aug-19-20',
#   '01:05PM',
#   'General Motors Reaffirms Focus on EVs; Over 40% of New China Vehicles to Be Electric'],
#  ['TSLA',
#   'Aug-19-20',
#   '12:53PM',
#   'Teslas Gigafactory Is Getting Bigger. What It Means for the Stock.'],
#  ['TSLA',
#   'Aug-19-20',
#   '11:25AM',
#   'Panasonic To Invest $100M In Tesla Battery Plant: Report'],
#  ['TSLA',
#   'Aug-19-20',
#   '10:29AM',
#   'Everything You Need to Know About the Newest Electric-Vehicle MakerCanoo'],
#  ['TSLA',
#   'Aug-19-20',
#   '10:21AM',
#   'GM Electrifies China Lineup to Challenge Teslas Early Lead'],
#  ['TSLA',
#   'Aug-19-20',
#   '09:28AM',
#   'The Stock Market Is Back to New Highs. Why the S&P 500 Still Has Room to Run.'],
#  ['TSLA',
#   'Aug-19-20',
#   '08:49AM',
#   "Tesla's stock set to slip, which would snap best 5-day performance in 6 weeks"],
#  ['TSLA',
#   'Aug-19-20',
#   '07:10AM',
#   'A Huge Tesla Bet Pays Off Big for one British\xa0Fund'],
#  ['TSLA',
#   'Aug-19-20',
#   '03:00AM',
#   'Tesla or Nio: Which EV Company is Geared to Race Ahead?'],
#  ['TSLA',
#   'Aug-19-20',
#   '02:30AM',
#   'Detroit and Germany Already Have Their Own Teslas'],
#  ['TSLA',
#   'Aug-18-20',
#   '07:14PM',
#   'Tesla Stock Has Been Soaring: Is It a Buy?'],
#  ['TSLA',
#   'Aug-18-20',
#   '05:00PM',
#   'Elon Musk Is Now the Worlds Fourth-Richest Person After an Epic $8 Billion Gain'],
#  ['TSLA',
#   'Aug-18-20',
#   '04:46PM',
#   'Heres the Real Reason Tesla Stock Is Soaring'],
#  ['TSLA',
#   'Aug-18-20',
#   '04:35PM',
#   "Tesla's Elon Musk Is Now the World's 4th Richest Person"],
#  ['TSLA',
#   'Aug-18-20',
#   '04:25PM',
#   'Tesla Inc. stock outperforms market on strong trading day'],
#  ['TSLA',
#   'Aug-18-20',
#   '03:15PM',
#   'New Tesla Model Y For Kids By Radio Flyer Is Available For Preorder'],
#  ['TSLA',
#   'Aug-18-20',
#   '03:08PM',
#   'Musks SpaceX Raises Almost $2 Billion in a Launch-Heavy Month'],
#  ['TSLA',
#   'Aug-18-20',
#   '03:01PM',
#   'Another EV Company Is Going Public. Heres What Separates It From Tesla and All the Rest.'],
#  ['TSLA',
#   'Aug-18-20',
#   '03:00PM',
#   'Radio Flyer teams up with Tesla to launch a tyke-sized Tesla Model Y'],
#  ['TSLA',
#   'Aug-18-20',
#   '02:18PM',
#   'Tesla Reportedly Ordering New Processors; Could Hint At Self-Driving Development'],
#  ['TSLA',
#   'Aug-18-20',
#   '12:25PM',
#   'Dow Jones Cuts Loss, S&P 500 Hits New High As Stocks Remain Mixed'],
#  ['TSLA',
#   'Aug-18-20',
#   '11:30AM',
#   'Dow Jones Flat, But S&P 500 Hits All-Time High; FANG Stock Gives New Buy Signal'],
#  ['TSLA',
#   'Aug-18-20',
#   '10:50AM',
#   'Bill Gates, Elon Musk, Jeff Bezos and the rest of the Oligarchic Dozen just reached a disturbing milestone'],
#  ['TSLA',
#   'Aug-18-20',
#   '10:11AM',
#   'GM Shares Soar on Electric-Vehicle Spin-Off Speculation'],
#  ['TSLA',
#   'Aug-18-20',
#   '10:10AM',
#   'Dow Jones Falls 100 Points Amid Earnings From Home Depot, Walmart; S&P 500 Hits Record High, While Amazon, Tesla Jump'],
#  ['TSLA',
#   'Aug-18-20',
#   '09:35AM',
#   'Tesla Shares Top Record High $1,900 On Wedbush Price Target Boost'],
#  ['TSLA',
#   'Aug-18-20',
#   '09:33AM',
#   "EV developer Canoo to go public via reverse merger with 'blank check' company Hennessy Capital Acquisition"],
#  ['TSLA',
#   'Aug-18-20',
#   '09:30AM',
#   "Uh-oh! Tesla Gets Into a Fight With China's Hottest E-Commerce Site"],
#  ['TSLA',
#   'Aug-18-20',
#   '08:28AM',
#   "Tesla's stock set to extend surge toward another record, but pares earlier premarket gains"],
#  ['TSLA',
#   'Aug-18-20',
#   '08:10AM',
#   'Buy GM Stock Now, Says Analyst Who Made a Winning Call With Nikola'],
#  ['TSLA',
#   'Aug-18-20',
#   '08:00AM',
#   'Nasdaq-100 ETF Hits Record High: 5 Stocks Powering the Rally'],
#  ['TSLA',
#   'Aug-18-20',
#   '07:53AM',
#   'Dow Jones Futures Rise On Earnings; Home Depot, Walmart Rally, While Tesla Surges 4%'],
#  ['TSLA', 'Aug-18-20', '07:27AM', 'Tesla Stock Had a Record Day on Monday'],
#  ['TSLA',
#   'Aug-18-20',
#   '07:00AM',
#   'EV startup Canoo to go public with blank-check firm at $2.4 bln valuation'],
#  ['TSLA',
#   'Aug-18-20',
#   '06:52AM',
#   'S&P 500 on Trend, Nvidia Ahead of Earnings, Tesla Targets, Trading Veeva Systems'],
#  ['TSLA',
#   'Aug-18-20',
#   '06:05AM',
#   '3 Reasons Why Intuitive Surgical Could Be Headed for a Stock Split'],
#  ['TSLA',
#   'Aug-18-20',
#   '04:42AM',
#   "SoftBank's $3.9B US Stock Bets Include Amazon, Netflix, Google, Tesla"],
#  ['TSLA',
#   'Aug-18-20',
#   '04:30AM',
#   'Elon Musk Is Now the Worlds Fourth-Richest Person'],
#  ['TSLA',
#   'Aug-18-20',
#   '03:47AM',
#   'Tesla Soars 11% After Wedbush Ramps Up PT On China Demand'],
#  ['TSLA',
#   'Aug-18-20',
#   '03:17AM',
#   'Tesla In A Simmering Discord With Chinese E-commerce Giant Pinduoduo Over Discounted Model 3 Sedans'],
#  ['TSLA',
#   'Aug-17-20',
#   '09:53PM',
#   'SoftBank Bets $3.9 Billion on U.S. Giants From Amazon to Tesla'],
#  ['TSLA',
#   'Aug-17-20',
#   '07:01PM',
#   'Bezos And Blackrock Are Pouring Billions Into This $30.7 Trillion Trend'],
#  ['TSLA',
#   'Aug-17-20',
#   '05:42PM',
#   'Will CARZ ETF Gain Despite Mixed Auto Earnings?'],
#  ['TSLA',
#   'Aug-17-20',
#   '05:05PM',
#   'Tesla Value Surpasses Consumer Giant P&G, Next Stop Walmart'],
#  ['TSLA',
#   'Aug-17-20',
#   '04:58PM',
#   'Nasdaq Hits New Record on NVIDIA, Tesla Upgrades'],
#  ['TSLA',
#   'Aug-17-20',
#   '04:30PM',
#   "Stock Market Today: Nasdaq Rolls, S&P Still Can't Catch the Bull"],
#  ['TSLA',
#   'Aug-17-20',
#   '04:25PM',
#   'Tesla Inc. stock outperforms market on strong trading day'],
#  ['TSLA',
#   'Aug-17-20',
#   '03:53PM',
#   'Elon Musk Looks For AI Experts As Tesla Develops Dojo Supercomputer'],
#  ['TSLA',
#   'Aug-17-20',
#   '03:06PM',
#   "Tesla's Gigafactory Berlin Approved For Next Phase Of Construction"],
#  ['TSLA',
#   'Aug-17-20',
#   '03:02PM',
#   "Tesla's stock tops $1,800, after soaring more than 30% in 4 days"],
#  ['TSLA', 'Aug-17-20', '02:59PM', 'Why NIO Stock Is Trading Higher Today'],
#  ['TSLA',
#   'Aug-17-20',
#   '01:55PM',
#   'Tesla Reported Bad News Out of China. Why Its Stock Is Rising.'],
#  ['TSLA',
#   'Aug-17-20',
#   '01:49PM',
#   'Top Stock Reports for Tesla, Disney & PepsiCo'],
#  ['TSLA',
#   'Aug-17-20',
#   '01:39PM',
#   "Tesla's Full Self-Driving Software To Make 'Quantum Leap,' Musk Says"],
#  ['TSLA',
#   'Aug-17-20',
#   '11:45AM',
#   'Dow Jones Dips, But Home Depot, Walmart Jump Ahead Of Earnings; 4 Dow Stocks Near Buy Points'],
#  ['TSLA',
#   'Aug-17-20',
#   '11:35AM',
#   'SoftBank builds $1.2 billion Amazon stake; invests in Netflix, Tesla'],
#  ['TSLA',
#   'Aug-17-20',
#   '11:27AM',
#   "GM's stock rallies as Deutsche Bank pushes for EV spinoff"],
#  ['TSLA', 'Aug-17-20', '11:07AM', 'Why Tesla Stock Jumped on Monday'],
#  ['TSLA',
#   'Aug-17-20',
#   '10:52AM',
#   "Wedbush Raises Tesla Price Target To $1,900, Calls China A 'Paradigm Changer'"],
#  ['TSLA',
#   'Aug-17-20',
#   '10:43AM',
#   'Tesla Hits Record After Wedbush Lifts Price-Target to $1,900'],
#  ['TSLA',
#   'Aug-17-20',
#   '10:01AM',
#   "Auto Stock Roundup: TSLA Stock Split, Ford Recalls, NIO's Q2 Show & More"],
#  ['TSLA', 'Aug-17-20', '09:54AM', "Tesla's China Registrations Sink in July"],
#  ['TSLA',
#   'Aug-17-20',
#   '09:51AM',
#   "Should GM Create an EV Spinoff? It's Complicated"],
#  ['TSLA',
#   'Aug-17-20',
#   '09:49AM',
#   'Dow Jones Rallies 50 Points, As Apple Hits Record High; JD.com, Nvidia And Tesla Jump'],
#  ['TSLA',
#   'Aug-17-20',
#   '09:30AM',
#   'The Case for Discretionary Spending in a Recession'],
#  ['TSLA',
#   'Aug-17-20',
#   '09:08AM',
#   'Tesla Stock Is Rising, Nvidia Is Jumping and the S&P 500 Is Targeting a Record High'],
#  ['TSLA',
#   'Aug-17-20',
#   '08:42AM',
#   'Options Measures Suggest Fervor for Technology Shares May Ebb'],
#  ['TSLA',
#   'Aug-17-20',
#   '08:12AM',
#   'Another Electric Vehicle Is Coming to Market. Teslas Crown May Be Up for Grabs.'],
#  ['TSLA', 'Aug-17-20', '08:05AM', '3 Stocks to Avoid This Week'],
#  ['TSLA',
#   'Aug-17-20',
#   '07:56AM',
#   'Dow Jones Futures: Stock Market Rally Sends Message; JD Earnings Top, Tesla Gets Price Target Hike'],
#  ['TSLA',
#   'Aug-17-20',
#   '06:33AM',
#   "Tesla's stock rallies into record territory after Wedbush raises price target"],
#  ['TSLA',
#   'Aug-17-20',
#   '06:05AM',
#   'RPT-BUZZ-U.S. stocks weekly: High level flirting'],
#  ['TSLA',
#   'Aug-17-20',
#   '04:45AM',
#   "Musk 'Begs' Twitter Followers To Trash Him On Wikipedia, And Chaos Ensues"],
#  ['TSLA',
#   'Aug-17-20',
#   '03:50AM',
#   "Tesla's China-Made Electric Vehicle Registrations Plunged 24% In July"],
#  ['TSLA', 'Aug-17-20', '01:38AM', 'Take Five: Impasse!'],
#  ['TSLA',
#   'Aug-16-20',
#   '10:00PM',
#   "Tesla App To Finally Get 'Embarrassingly Late' Two-Factor Authentication, Musk Says"],
#  ['TSLA',
#   'Aug-16-20',
#   '03:00PM',
#   'Investors Are Looking To China To Find The Next Tesla'],
#  ['TSLA',
#   'Aug-16-20',
#   '03:44AM',
#   'Merrill Lynch Upgrades Tesla To Hold, More Than Doubles PT'],
#  ['TSLA',
#   'Aug-15-20',
#   '03:34PM',
#   'Its Time to Build Cash to Take Advantage of Stocks Coming Tumble'],
#  ['TSLA',
#   'Aug-15-20',
#   '12:58PM',
#   '3 Revolutionary Stocks That Can Make You Rich'],
#  ['TSLA',
#   'Aug-15-20',
#   '07:07AM',
#   'Forget Pre-Split Tesla: These 3 Stocks Are Better Buys'],
#  ['TSLA',
#   'Aug-15-20',
#   '03:55AM',
#   "China's CATL is developing new EV battery with no nickel, cobalt, executive says"],
#  ['TSLA',
#   'Aug-15-20',
#   '03:13AM',
#   "China's CATL is developing new EV battery with no nickel, cobalt, exec says"],
#  ['TSLA', 'Aug-14-20', '09:16PM', 'Not Your Fathers Tesla'],
#  ['TSLA',
#   'Aug-14-20',
#   '08:59PM',
#   'The Bear Market Is Nearing an End. The Bubble Might Just Be Getting Started.'],
#  ['TSLA',
#   'Aug-14-20',
#   '07:30PM',
#   'Inflation, Economic Recovery, and Tesla Stock'],
#  ['TSLA',
#   'Aug-14-20',
#   '04:55PM',
#   '4 Top Stock Trades for Monday: TSLA, IQ, ACB, AMAT'],
#  ['TSLA',
#   'Aug-14-20',
#   '04:27PM',
#   "Winklelvoss Twins Explain Musk's Plan For Gold Mining In Space To Dave Portnoy"],
#  ['TSLA',
#   'Aug-14-20',
#   '04:25PM',
#   'Tesla Inc. stock outperforms market on strong trading day'],
#  ['TSLA',
#   'Aug-14-20',
#   '04:14PM',
#   "Tesla's Smart Summon Technology Detailed In Patent Application"],
#  ['TSLA', 'Aug-14-20', '03:45PM', "Cramer's 7 Deadly Sins Of Stock Investing"],
#  ['TSLA',
#   'Aug-14-20',
#   '03:25PM',
#   'Nasdaq Stays Close to Record Highs; Upgrades Lift Tesla; Applied Materials Gets an Earnings Boost'],
#  ['TSLA',
#   'Aug-14-20',
#   '03:01PM',
#   'Dow Jones Edges Higher In New Bid For 28,000; Tesla, AMAT Stock Lead Nasdaq'],
#  ['TSLA',
#   'Aug-14-20',
#   '02:08PM',
#   'Apple, Home Depot, Roku - Latest Upgrades and Downgrades'],
#  ['TSLA',
#   'Aug-14-20',
#   '12:59PM',
#   'GM Could Unlock Value by Spinning Off Its EV Business, Says Analyst. Heres What It Could Be Worth.'],
#  ['TSLA',
#   'Aug-14-20',
#   '12:15PM',
#   'Dow Jones Reverses Higher Despite Weak Retail Sales; Apple Stock Lags'],
#  ['TSLA',
#   'Aug-14-20',
#   '12:00PM',
#   'Dow Jones Reverses From 125 Point Fall On Weak Retail Sales; Tesla Jumps On Upgrades, While IQiyi Plunges 15% On SEC Probe'],
#  ['TSLA',
#   'Aug-14-20',
#   '11:58AM',
#   'Tesla stock propelled higher by BofA and Morgan Stanley upgrades'],
#  ['GOOG', 'Aug-19-20', '02:00PM', 'GOOGL Looks Ready to Go Even Higher'],
#  ['GOOG',
#   'Aug-19-20',
#   '01:15PM',
#   'Zynga Dethrones Activision Blizzard as the Largest U.S. Mobile Video Game Company'],
#  ['GOOG',
#   'Aug-19-20',
#   '01:14PM',
#   'Zoom Video to Soon Appear on Amazon, Facebook, and Google Smart Display Devices'],
#  ['GOOG',
#   'Aug-19-20',
#   '12:36PM',
#   'Zoom for Home App to Appear on Facebook Portal Devices'],
#  ['GOOG',
#   'Aug-19-20',
#   '11:28AM',
#   "Zoom Video's for home service to expand to Amazon's Echo, Facebook's Portal and Google's Nest"],
#  ['GOOG',
#   'Aug-19-20',
#   '11:01AM',
#   "Alphabet Inc.'s (NASDAQ:GOOG.L) Earnings Haven't Escaped The Attention Of Investors"],
#  ['GOOG',
#   'Aug-19-20',
#   '09:28AM',
#   'The Stock Market Is Back to New Highs. Why the S&P 500 Still Has Room to Run.'],
#  ['GOOG',
#   'Aug-19-20',
#   '08:14AM',
#   "Dow Jones Futures: Amazon, Google Flash Buy Signals In Stock Market Rally; Target, Lowe's Crush Views"],
#  ['GOOG',
#   'Aug-19-20',
#   '08:00AM',
#   "[video]Apple's Battle with Epic Games Shouldn't Do Major Financial Harm"],
#  ['GOOG',
#   'Aug-19-20',
#   '06:55AM',
#   'This Day In Market History: The Google IPO'],
#  ['GOOG',
#   'Aug-19-20',
#   '05:23AM',
#   'Amazon and Ambanis Jio Are Spoiling for an Epic India Fight'],
#  ['GOOG',
#   'Aug-19-20',
#   '02:36AM',
#   'Google launches Kormo app in India to help people find entry-level jobs'],
#  ['GOOG',
#   'Aug-19-20',
#   '02:20AM',
#   'Times of India Publisher Mulls Minority Stake Sale in Internet Unit'],
#  ['GOOG',
#   'Aug-18-20',
#   '09:00PM',
#   'Hagens Berman: Android App Developers Sue Google Claiming Play Store Illegally Monopolizes Markets for Android App Distribution and In-App Payment Processing, Violates Antitrust Laws'],
#  ['GOOG',
#   'Aug-18-20',
#   '05:53PM',
#   'Apple and Epic Ramp Up Battle Over Fortnite and the App Store'],
#  ['GOOG',
#   'Aug-18-20',
#   '04:25PM',
#   'Apple Inc. stock rises Tuesday, outperforms market'],
#  ['GOOG',
#   'Aug-18-20',
#   '04:25PM',
#   'Amazon.com Inc. stock outperforms competitors on strong trading day'],
#  ['GOOG',
#   'Aug-18-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock rises Tuesday, outperforms market'],
#  ['GOOG',
#   'Aug-18-20',
#   '04:11PM',
#   'School Reopening Is a Disaster in the Making'],
#  ['GOOG',
#   'Aug-18-20',
#   '04:06PM',
#   'The Stock Markets Improbable Recovery Explained'],
#  ['GOOG', 'Aug-18-20', '03:04PM', 'Why Doing Homework Is Important'],
#  ['GOOG',
#   'Aug-18-20',
#   '01:26PM',
#   'Why Cheetah Mobile Stock Briefly Sprinted Higher'],
#  ['GOOG', 'Aug-18-20', '12:20PM', 'Oracle and TikTok? Thats Just Weird'],
#  ['GOOG',
#   'Aug-18-20',
#   '11:37AM',
#   'What Google and Amazon are doing to comply with Californias new privacy law'],
#  ['GOOG',
#   'Aug-18-20',
#   '10:50AM',
#   'Bill Gates, Elon Musk, Jeff Bezos and the rest of the Oligarchic Dozen just reached a disturbing milestone'],
#  ['GOOG', 'Aug-18-20', '10:29AM', "Why Hasn't Roku (ROKU) Broken Out?"],
#  ['GOOG',
#   'Aug-18-20',
#   '09:25AM',
#   'How to Buy Stocks During the COVID-19 Pandemic'],
#  ['GOOG',
#   'Aug-18-20',
#   '09:00AM',
#   'Bluetooth SIG works to include wearables in COVID-19 exposure notification systems'],
#  ['GOOG',
#   'Aug-18-20',
#   '09:00AM',
#   "As One Might Expect, Retailers Don't Like Using Amazon for Cloud Services"],
#  ['GOOG',
#   'Aug-18-20',
#   '08:30AM',
#   'SoftBank Is Betting Big on U.S. Tech Megacaps'],
#  ['GOOG',
#   'Aug-18-20',
#   '07:32AM',
#   'Worlds Biggest Wealth Fund Wants Clarification on New CEO'],
#  ['GOOG',
#   'Aug-18-20',
#   '07:15AM',
#   '3 Industry Trends Accelerating Cord-Cutting'],
#  ['GOOG',
#   'Aug-18-20',
#   '06:00AM',
#   'Covid-Era Tech Grads Launch Careers From Parents Homes'],
#  ['GOOG',
#   'Aug-18-20',
#   '04:42AM',
#   "SoftBank's $3.9B US Stock Bets Include Amazon, Netflix, Google, Tesla"],
#  ['GOOG',
#   'Aug-18-20',
#   '03:48AM',
#   'Turkeys Gaming Startups Have Attracted $2.4 Billion in Investments Since 2015'],
#  ['GOOG',
#   'Aug-17-20',
#   '10:08PM',
#   'Apple Threatens to Terminate Epics Developer Account'],
#  ['GOOG',
#   'Aug-17-20',
#   '09:53PM',
#   'SoftBank Bets $3.9 Billion on U.S. Giants From Amazon to Tesla'],
#  ['GOOG',
#   'Aug-17-20',
#   '08:28PM',
#   'Report: Amazon in Discussions to Buy Minority Stake in Rackspace'],
#  ['GOOG',
#   'Aug-17-20',
#   '05:55PM',
#   'Epic Games Says Apple Has Threatened to Cut Off Fortnite Makers Developer Access'],
#  ['GOOG',
#   'Aug-17-20',
#   '04:36PM',
#   "Alphabet-Backed Startup To Build Self-Driving 'Road Of The Future'"],
#  ['GOOG',
#   'Aug-17-20',
#   '04:27PM',
#   'Fortnites impact could be Epic on antitrust investigations of Big Tech'],
#  ['GOOG',
#   'Aug-17-20',
#   '04:25PM',
#   'Apple Inc. stock falls Monday, underperforms market'],
#  ['GOOG',
#   'Aug-17-20',
#   '04:25PM',
#   'Amazon.com Inc. stock rises Monday, outperforms market'],
#  ['GOOG',
#   'Aug-17-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock rises Monday, outperforms market'],
#  ['GOOG',
#   'Aug-17-20',
#   '03:57PM',
#   "Report: Alphabet's Google in Talks for Stake in India's ShareChat"],
#  ['GOOG',
#   'Aug-17-20',
#   '03:26PM',
#   'New Rule Threatens Free Google Search and YouTube in Australia'],
#  ['GOOG',
#   'Aug-17-20',
#   '01:00PM',
#   'Theres a\xa0Better Way to Identify When Recessions Start'],
#  ['GOOG',
#   'Aug-17-20',
#   '12:49PM',
#   'Amazon in talks to invest in cloud-services company Rackspace: report'],
#  ['GOOG',
#   'Aug-17-20',
#   '12:45PM',
#   "2 Pros Offer Their Take On The 'Fortnite'-Apple Lawsuit"],
#  ['GOOG',
#   'Aug-17-20',
#   '11:54AM',
#   'Link Marines Are Making an Obscure Cryptocurrency Red Hot'],
#  ['GOOG',
#   'Aug-17-20',
#   '11:52AM',
#   'Rackspace Soars After Amazon Said To Be In Talks for Stake'],
#  ['GOOG',
#   'Aug-17-20',
#   '11:22AM',
#   'Global Markets Review: Fortnite vs. Apple and Google'],
#  ['GOOG',
#   'Aug-17-20',
#   '10:03AM',
#   "Apple's 'extreme' app policies give Google defense in Fortnite antitrust suit"],
#  ['GOOG',
#   'Aug-17-20',
#   '09:45AM',
#   'The S&P 500 Will Rise 7% More This Year, Goldman Sachs Says. Heres Why.'],
#  ['GOOG',
#   'Aug-17-20',
#   '09:38AM',
#   'Google warns that if it has to pay for news content in Australia, the country could lose its free services'],
#  ['GOOG',
#   'Aug-17-20',
#   '08:42AM',
#   'Robinhood Investors Love These 4 Terrible Tech Stocks'],
#  ['GOOG',
#   'Aug-17-20',
#   '07:00AM',
#   'Startups Tap a New Talent Pool: Pandemic-Weary College Students'],
#  ['GOOG',
#   'Aug-17-20',
#   '06:30AM',
#   'Apple Faces a Well-Armed Enemy in Fortnite Battle Royale'],
#  ['GOOG',
#   'Aug-17-20',
#   '06:28AM',
#   'Rackspace Jumps on Possible Amazon Stake Purchase, Reuters Reports'],
#  ['GOOG',
#   'Aug-17-20',
#   '01:57AM',
#   'Google Mulling Investment In Indias ShareChat- Report'],
#  ['GOOG',
#   'Aug-16-20',
#   '11:37PM',
#   'Google goes public with rebuke on Australia antitrust law'],
#  ['GOOG',
#   'Aug-16-20',
#   '11:33PM',
#   'Google says Australian antitrust law would hit small content creators'],
#  ['GOOG',
#   'Aug-16-20',
#   '10:00PM',
#   "Tesla App To Finally Get 'Embarrassingly Late' Two-Factor Authentication, Musk Says"],
#  ['GOOG',
#   'Aug-16-20',
#   '01:14PM',
#   "Epic Games Says Battle Against Apple, Google A Push For 'Fair Competition'"],
#  ['GOOG',
#   'Aug-16-20',
#   '08:15AM',
#   '3 Top Tech Stocks to Buy if the Market Crashes'],
#  ['GOOG', 'Aug-16-20', '06:09AM', 'Is Dividend Investing Dead?'],
#  ['GOOG',
#   'Aug-15-20',
#   '07:00PM',
#   'U.S. Stocks Are Keeping Chinas Amateur Investors Awake at Night'],
#  ['GOOG',
#   'Aug-15-20',
#   '01:27PM',
#   'Trump Orders TikToks Chinese Parent to Sell Its U.S. Assets'],
#  ['GOOG',
#   'Aug-15-20',
#   '01:00PM',
#   'Epic Games Kicks Off a Brilliantly Timed Assault on Apple and Google'],
#  ['GOOG', 'Aug-15-20', '12:39PM', 'Coho Capital 2020 Q2 Commentary: SPOT On'],
#  ['GOOG',
#   'Aug-15-20',
#   '08:07AM',
#   '"Fortnite" Publisher Epic Games Wants to Change the App Store Business From the Inside'],
#  ['GOOG',
#   'Aug-15-20',
#   '07:31AM',
#   'Here is How You Can Buy Alphabet Stock for Under $2'],
#  ['GOOG',
#   'Aug-14-20',
#   '07:21PM',
#   'Apple, Tesla Stock Splits Could Encourage Others'],
#  ['GOOG',
#   'Aug-14-20',
#   '06:33PM',
#   'Facebook Joins the List of Apple App Store Critics'],
#  ['GOOG',
#   'Aug-14-20',
#   '06:32PM',
#   'ESG Investors Can Beat the Market Without Apple, Amazon. Heres How.'],
#  ['GOOG',
#   'Aug-14-20',
#   '05:23PM',
#   "Column: The maker of 'Fortnite' complains that Apple and Google are monopolists. No kidding"],
#  ['GOOG',
#   'Aug-14-20',
#   '04:41PM',
#   'Facebook Says Apple In-App Fees Hurt Businesses During Covid'],
#  ['GOOG',
#   'Aug-14-20',
#   '04:36PM',
#   "Gamers, Companies Show Support After Fortnite Developer Sues Alphabet's Google"],
#  ['GOOG',
#   'Aug-14-20',
#   '04:25PM',
#   'Apple Inc. stock outperforms market despite losses on the day'],
#  ['GOOG',
#   'Aug-14-20',
#   '04:25PM',
#   'Amazon.com Inc. stock falls Friday, underperforms market'],
#  ['GOOG',
#   'Aug-14-20',
#   '04:25PM',
#   'Alphabet Inc. Cl A stock underperforms Friday when compared to competitors'],
#  ['GOOG',
#   'Aug-14-20',
#   '01:54PM',
#   'Analysts Are Sounding Red Alarms About a Microsoft and TikTok Combination'],
#  ['GOOG',
#   'Aug-14-20',
#   '12:17PM',
#   '"Fortnite\'s" Epic Battle With Apple and Google Escalates'],
#  ['GOOG',
#   'Aug-14-20',
#   '12:15PM',
#   'Fortnite Battles Big Tech: Why Epic Games Is Suing Apple, Google Over Their App Store Monopolies'],
#  ['GOOG',
#   'Aug-14-20',
#   '10:16AM',
#   "Are Investors Ignoring a Real Risk to Apple's Future?"],
#  ['GOOG',
#   'Aug-14-20',
#   '08:00AM',
#   'Facebook\xa0Shouldnt Have to Pay Publishers for News'],
#  ['GOOG', 'Aug-14-20', '07:58AM', 'Tesla Stock Is Hard to Hate'],
#  ['GOOG',
#   'Aug-14-20',
#   '07:15AM',
#   'How DuckDuckGo is taking on Googles search business with a simple premise'],
#  ['GOOG',
#   'Aug-14-20',
#   '01:16AM',
#   'Google stops responding directly to data requests from Hong Kong government'],
#  ['GOOG',
#   'Aug-14-20',
#   '12:56AM',
#   'Kamala Harriss Indian Connections Spark Social Media Frenzy'],
#  ['GOOG',
#   'Aug-13-20',
#   '11:10PM',
#   "Apple, Google Taken To Court Over 'Fortnite' Removal From App Stores"],
#  ['GOOG',
#   'Aug-13-20',
#   '09:44PM',
#   'Fortnite maker accuses Apple, Google of illegal monopolistic practices in tech battle royale'],
#  ['GOOG',
#   'Aug-13-20',
#   '09:35PM',
#   'Fortnite Maker Sues Apple and Google Over App Store Dispute'],
#  ['GOOG',
#   'Aug-13-20',
#   '08:14PM',
#   'Game Makers Give Apple the Antitrust Grilling Congress Didnt'],
#  ['GOOG', 'Aug-13-20', '06:37PM', 'Coda CEO on Work Productivity'],
#  ['GOOG',
#   'Aug-13-20',
#   '06:23PM',
#   'Crime-Tracking App Citizen Now Alerts Users to Infection Risk'],
#  ['GOOG',
#   'Aug-13-20',
#   '05:54PM',
#   "U.S. Justice Department going 'full tilt' on tech antitrust probe - official"],
#  ['GOOG',
#   'Aug-13-20',
#   '04:56PM',
#   'Epic Games Brings a New Payment System to "Fortnite," and It Comes With a 20% Discount'],
#  ['GOOG',
#   'Aug-13-20',
#   '04:25PM',
#   'Apple Inc. stock rises Thursday, outperforms market'],
#  ['GOOG',
#   'Aug-13-20',
#   '04:25PM',
#   'Amazon.com Inc. stock falls Thursday, still outperforms market']]

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.tail()
# Out:
#     ticker        date     time  \
# 295   GOOG  2020-08-13  06:23PM
# 296   GOOG  2020-08-13  05:54PM
# 297   GOOG  2020-08-13  04:56PM
# 298   GOOG  2020-08-13  04:25PM
# 299   GOOG  2020-08-13  04:25PM
#
#                                               headline    neg    neu    pos  \
# 295  Crime-Tracking App Citizen Now Alerts Users to...  0.208  0.792  0.000
# 296  U.S. Justice Department going 'full tilt' on t...  0.000  0.746  0.254
# 297  Epic Games Brings a New Payment System to "For...  0.000  1.000  0.000
# 298  Apple Inc. stock rises Thursday, outperforms m...  0.000  1.000  0.000
# 299  Amazon.com Inc. stock falls Thursday, still ou...  0.000  1.000  0.000
#
#      compound
# 295   -0.2732
# 296    0.5267
# 297    0.0000
# 298    0.0000
# 299    0.0000

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()

# %%
sentiment = parsed_and_scored_news
sentiment
# Out:
#     ticker        date     time  \
# 0     AMZN  2020-08-19  02:37PM
# 1     AMZN  2020-08-19  01:50PM
# 2     AMZN  2020-08-19  01:30PM
# 3     AMZN  2020-08-19  01:14PM
# 4     AMZN  2020-08-19  01:10PM
# ..     ...         ...      ...
# 295   GOOG  2020-08-13  06:23PM
# 296   GOOG  2020-08-13  05:54PM
# 297   GOOG  2020-08-13  04:56PM
# 298   GOOG  2020-08-13  04:25PM
# 299   GOOG  2020-08-13  04:25PM
#
#                                               headline    neg    neu    pos  \
# 0    Why Target Stock Is Hopping and Walmart Is Sli...  0.000  0.784  0.216
# 1    Trump Likes The Idea Of Oracle Buying TikTok. ...  0.161  0.640  0.199
# 2    Amazon to add thousands of jobs to Phoenix met...  0.000  0.841  0.159
# 3    Zoom Video to Soon Appear on Amazon, Facebook,...  0.000  0.714  0.286
# 4    1 Surprising Number From Walmart's Second Quar...  0.000  0.595  0.405
# ..                                                 ...    ...    ...    ...
# 295  Crime-Tracking App Citizen Now Alerts Users to...  0.208  0.792  0.000
# 296  U.S. Justice Department going 'full tilt' on t...  0.000  0.746  0.254
# 297  Epic Games Brings a New Payment System to "For...  0.000  1.000  0.000
# 298  Apple Inc. stock rises Thursday, outperforms m...  0.000  1.000  0.000
# 299  Amazon.com Inc. stock falls Thursday, still ou...  0.000  1.000  0.000
#
#      compound
# 0      0.5106
# 1      0.1386
# 2      0.1779
# 3      0.5267
# 4      0.3400
# ..        ...
# 295   -0.2732
# 296    0.5267
# 297    0.0000
# 298    0.0000
# 299    0.0000
#
# [300 rows x 8 columns]

# %%
sentiment["ticker"].value_counts()
# Out:
# TSLA    100
# AMZN    100
# GOOG    100
# Name: ticker, dtype: int64

# %%
news_grouped = sentiment.groupby(['ticker','date'], as_index=False).sum()
news_grouped
# Out:
#    ticker        date    neg     neu    pos  compound
# 0    AMZN  2020-08-18  2.164  50.988  6.847    4.9680
# 1    AMZN  2020-08-19  3.444  29.880  6.675    4.1440
# 2    GOOG  2020-08-13  0.901   8.845  0.254   -0.9709
# 3    GOOG  2020-08-14  3.003  13.786  1.210   -2.8779
# 4    GOOG  2020-08-15  0.226   5.377  0.397    0.2295
# 5    GOOG  2020-08-16  0.989   4.661  0.349   -0.9254
# 6    GOOG  2020-08-17  1.997  20.800  2.203    0.3190
# 7    GOOG  2020-08-18  1.473  18.645  1.882   -0.1148
# 8    GOOG  2020-08-19  0.720  11.135  1.144    0.6806
# 9    TSLA  2020-08-14  0.676  13.023  1.301    1.1038
# 10   TSLA  2020-08-15  0.486   3.717  0.798    0.4654
# 11   TSLA  2020-08-16  0.213   2.787  0.000   -0.4019
# 12   TSLA  2020-08-17  1.356  30.957  2.687    1.7212
# 13   TSLA  2020-08-18  1.012  26.591  2.397    2.0571
# 14   TSLA  2020-08-19  0.000  11.225  0.775    1.4342

# %%
type(news_grouped)
# Out:
# pandas.core.frame.DataFrame

# %%
amzn = news_grouped.loc[news_grouped['ticker']=='AMZN']
amzn
# Out:
#   ticker        date    neg     neu    pos  compound
# 0   AMZN  2020-08-18  2.164  50.988  6.847     4.968
# 1   AMZN  2020-08-19  3.444  29.880  6.675     4.144

# %%
goog = news_grouped.loc[news_grouped['ticker']=='GOOG']
goog
# Out:
#   ticker        date    neg     neu    pos  compound
# 2   GOOG  2020-08-13  0.901   8.845  0.254   -0.9709
# 3   GOOG  2020-08-14  3.003  13.786  1.210   -2.8779
# 4   GOOG  2020-08-15  0.226   5.377  0.397    0.2295
# 5   GOOG  2020-08-16  0.989   4.661  0.349   -0.9254
# 6   GOOG  2020-08-17  1.997  20.800  2.203    0.3190
# 7   GOOG  2020-08-18  1.473  18.645  1.882   -0.1148
# 8   GOOG  2020-08-19  0.720  11.135  1.144    0.6806

# %%
tsla = news_grouped.loc[news_grouped['ticker']=='TSLA']
tsla
# Out:
#    ticker        date    neg     neu    pos  compound
# 9    TSLA  2020-08-14  0.676  13.023  1.301    1.1038
# 10   TSLA  2020-08-15  0.486   3.717  0.798    0.4654
# 11   TSLA  2020-08-16  0.213   2.787  0.000   -0.4019
# 12   TSLA  2020-08-17  1.356  30.957  2.687    1.7212
# 13   TSLA  2020-08-18  1.012  26.591  2.397    2.0571
# 14   TSLA  2020-08-19  0.000  11.225  0.775    1.4342

# %%
# Export file as a CSV, without the Pandas index, but with the header
amzn.to_csv("amzn.csv", index=False, header=True)
goog.to_csv("goog.csv", index=False, header=True)
tsla.to_csv("tsla.csv", index=False, header=True)
